# %% [markdown]
# ### Height Weight Prediction

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'], df['Height'])

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
X = df[['Height']]
y = df['Weight']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.22424512],
#        [ 0.81355586],
#        [-2.11993884],
#        [ 1.51759459],
#        [ 0.16818703],
#        [ 1.10690534],
#        [-1.23989043],
#        [ 1.57626449]])

# %%
# Linear regression
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

model = regression.fit(x_train, y_train)

# %%
y_pred = regression.predict(x_test)

# %%
# pltting data and best fit line 
plt.scatter(x_train, y_train)
plt.plot(x_train, regression.predict(x_train))

# %%
model.coef_
# Out:
# array([14.89745951])

# %%
print(model.intercept_)
# Out:
# 71.6

# %%
# performance matrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print("MSE : ", mse)
print("MAE: ",mae)
print("RMSE: ", rmse)
# Out:
# MSE :  76.8840076543612
# MAE:  7.39197748064743
# RMSE:  8.768352619184586

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8053569426471868

# %% [markdown]
# ### Study Hours → Marks

# %%
data = pd.read_csv('dataset1.csv')

# %%
data.head()
# Out:
#    study_hours  marks
# 0            1     35
# 1            2     40
# 2            3     50
# 3            4     55
# 4            5     60

# %%
plt.scatter(data['study_hours'], data['marks'])

# %%
data.corr()
# Out:
#              study_hours     marks
# study_hours     1.000000  0.997486
# marks           0.997486  1.000000

# %%
sns.pairplot(data)

# %%
x = data[['study_hours']]
Y = data['marks']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, Y, test_size= 0.33, random_state= 42)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.17591459],
#        [-1.72928616],
#        [-0.06917145],
#        [-2.14431484]])

# %%
reg = LinearRegression()
mod = reg.fit(X_train, Y_train)

# %%
mod
# Out:
# LinearRegression()

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([83.33971292, 43.38277512, 66.215311  , 37.67464115])

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, reg.predict(X_train))

# %%
MeanSE= mean_squared_error(Y_test, Y_pred)
MeanAE = mean_absolute_error(Y_test, Y_pred)
RMSE = np.sqrt(MeanSE)
r2 = r2_score(Y_test, Y_pred)

# %%
print(MeanSE)
print(MeanAE)
print(RMSE)
print(r2)
# Out:
# 5.707601703257708
# 2.233253588516746
# 2.3890587483897727
# 0.9858962737834559

# %% [markdown]
# ### Area → House Price

# %%
dataframe = pd.read_csv('area_house_price.csv')

# %%
dataframe.head()
# Out:
#    area_sqft    price
# 0        500  1500000
# 1        600  1800000
# 2        700  2100000
# 3        800  2500000
# 4        900  2800000

# %%
plt.scatter(dataframe['area_sqft'], dataframe['price'])

# %%
dataframe.corr()
# Out:
#            area_sqft    price
# area_sqft    1.00000  0.99665
# price        0.99665  1.00000

# %%
xx= dataframe[['area_sqft']]
yy= dataframe['price']

# %%
xx_train, xx_test, yy_train, yy_test = train_test_split(xx,yy,test_size = 0.33, random_state = 42)

# %%
xx_train = scaler.fit_transform(xx_train)
xx_test = scaler.transform(xx_test)

# %%
xx_test
# Out:
# array([[ 1.17591459],
#        [-1.72928616],
#        [-0.06917145],
#        [-2.14431484]])

# %%
modell= LinearRegression().fit(xx_train, yy_train)

# %%
yy_pred = modell.predict(xx_test)

# %%
plt.scatter(xx_train, yy_train)
plt.plot(xx_train, modell.predict(xx_train))

# %%
mmse = mean_squared_error(yy_test, yy_pred)
mmae= mean_absolute_error(yy_test, yy_pred)
rrmse = np.sqrt(mmse)
rr2 = r2_score(yy_test, yy_pred)

print(mmse)
print(mmae)
print(rrmse)
print(rr2)
# Out:
# 25573933746.93794
# 127272.72727272724
# 159918.52221346323
# 0.982147341188874

# %%
print(modell.coef_)
# Out:
# [979928.82381027]

# %%
train_r2 = model.score(xx_train, yy_train)
test_r2 = model.score(xx_test, yy_test)

print(train_r2, test_r2)
# Out:
# -11.50695526766823 -5.278963756723361
